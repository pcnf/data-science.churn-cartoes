# %%
# !pip install -r requirements.txt

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn import metrics
import lightgbm as lgbm

import awswrangler as wr
import pandas as pd

# %%
df = wr.s3.read_parquet('s3://neon-datascience-sandbox/churn-cartoes/main')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2188874 entries, 0 to 2188873
# Data columns (total 13 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   clientid                        Int64
#  1   ticket_mean_value               float64
#  2   total_transactions              Int64
#  3   data_min                        string
#  4   data_max                        string
#  5   time_diff                       Int64
#  6   mean_time_between_transactions  float64
#  7   presumedincome                  float64
#  8   age                             float64
#  9   ageneon                         Int64
#  10  GH_VL                           float64
#  11  tempo_sem_transacao             Int64
#  12  churn_flag                      Int64
# dtypes: Int64(6), float64(5), string(2)
# memory usage: 229.6 MB

# %% [markdown]
# ## Lightgbm

# %%
features = ['ticket_mean_value', 'total_transactions', 'mean_time_between_transactions', 'age', 'ageneon', 'GH_VL', 'presumedincome']
target = ['churn_flag']

# %%
base_treino = df.sample(frac=0.8,random_state=0)
base_teste = df.drop(base_treino.index)

# %%
Xtrain = base_treino[features].astype('float64')
ytrain = base_treino[target].astype('float64')

Xtest = base_teste[features].astype('float64')
ytest = base_teste[target].astype('float64')

# %%
model = lgbm.LGBMClassifier(learning_rate=0.09,max_depth=-5,random_state=42)
model.fit(Xtrain,ytrain, eval_set=[(Xtest,ytest),(Xtrain,ytrain)], eval_metric='auc')
# Out:
# /opt/conda/envs/datalake/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [LightGBM] [Info] Number of positive: 24185, number of negative: 1726914
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011387 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1127
# [LightGBM] [Info] Number of data points in the train set: 1751099, number of used features: 7
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.013811 -> initscore=-4.268359
# [LightGBM] [Info] Start training from score -4.268359
# LGBMClassifier(learning_rate=0.09, max_depth=-5, random_state=42)

# %%
print('Training accuracy {:.4f}'.format(model.score(Xtrain,ytrain)))
print('Testing accuracy {:.4f}'.format(model.score(Xtest,ytest)))
print(metrics.classification_report(ytest,model.predict(Xtest)))
# Out:
# Training accuracy 0.9861
# Testing accuracy 0.9859
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99    431716
#          1.0       0.00      0.00      0.00      6059
#
#     accuracy                           0.99    437775
#    macro avg       0.49      0.50      0.50    437775
# weighted avg       0.97      0.99      0.98    437775

# %%
metrics.plot_confusion_matrix(model,Xtest,ytest,cmap='Blues_r')

lgbm.plot_importance(model)

lgbm.plot_metric(model)

lgbm.plot_tree(model,figsize=(30,40))
# Out:
# /opt/conda/envs/datalake/lib/python3.8/site-packages/lightgbm/plotting.py:381: UserWarning: More than one metric available, picking one to plot.
#   _log_warning("More than one metric available, picking one to plot.")
# <AxesSubplot:>

# %% [markdown]
# ___

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression as LR
from sklearn.metrics import f1_score

features = ['ticket_mean_value', 'total_transactions', 'mean_time_between_transactions', 'age', 'ageneon', 'GH_VL', 'presumedincome']
target = ['churn_flag']

X = base_treino[features].astype('float64')
y = base_treino[target].astype('float64')

X = X.fillna(X.mean())
y = y.fillna(y.mean())

X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size = 0.3, random_state = 42)

from sklearn.linear_model import LogisticRegression as LR
from sklearn.metrics import f1_score

logReg = LR(verbose = True, solver = 'newton-cg')
logReg.fit(X_treino, y_treino)
y_pred = logReg.predict(X_teste)
y_pred_proba = logReg.predict_proba(X_teste)
f1 = f1_score(y_teste, y_pred)
print("f1_score: ",f1)
# Out:
# /opt/conda/envs/datalake/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# f1_score:  0.0

# %% [markdown]
# _____

# %% [markdown]
# ## Catboost

# %%
from catboost import CatBoostClassifier

# %%
features = ['ticket_mean_value', 'total_transactions', 'mean_time_between_transactions', 'age', 'ageneon', 'GH_VL', 'presumedincome']
target = ['churn_flag']

# %%
base_treino = base_frac.sample(frac=0.8,random_state=0)
base_teste = base_frac.drop(base_treino.index)



X_treino = base_treino[features].values
y_treino = base_treino[target].values


X_teste = base_teste[features].values
y_teste = base_teste[target].values


# Initialize CatBoostClassifier
model = CatBoostClassifier(iterations=100,
                           learning_rate=1,
                           depth=2)
# Fit model
model.fit(X_treino, y_treino, plot=True)
# Get predicted classes
preds_class = model.predict(X_teste)
# Get predicted probabilities for each class
preds_proba = model.predict_proba(X_teste)
# Get predicted RawFormulaVal
preds_raw = model.predict(X_teste, prediction_type='RawFormulaVal')
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.1594639	total: 86.5ms	remaining: 8.56s
# 1:	learn: 0.0873684	total: 119ms	remaining: 5.85s
# 2:	learn: 0.0670285	total: 150ms	remaining: 4.85s
# 3:	learn: 0.0609095	total: 197ms	remaining: 4.74s
# 4:	learn: 0.0587617	total: 225ms	remaining: 4.28s
# 5:	learn: 0.0584640	total: 252ms	remaining: 3.96s
# 6:	learn: 0.0582726	total: 279ms	remaining: 3.71s
# 7:	learn: 0.0581246	total: 306ms	remaining: 3.52s
# 8:	learn: 0.0578274	total: 333ms	remaining: 3.37s
# 9:	learn: 0.0577193	total: 360ms	remaining: 3.24s
# 10:	learn: 0.0576049	total: 387ms	remaining: 3.13s
# 11:	learn: 0.0575280	total: 414ms	remaining: 3.04s
# 12:	learn: 0.0574474	total: 441ms	remaining: 2.95s
# 13:	learn: 0.0573849	total: 468ms	remaining: 2.88s
# 14:	learn: 0.0573321	total: 495ms	remaining: 2.81s
# 15:	learn: 0.0571453	total: 523ms	remaining: 2.75s
# 16:	learn: 0.0570744	total: 550ms	remaining: 2.69s
# 17:	learn: 0.0570171	total: 579ms	remaining: 2.63s
# 18:	learn: 0.0569480	total: 606ms	remaining: 2.58s
# 19:	learn: 0.0569376	total: 634ms	remaining: 2.54s
# 20:	learn: 0.0569109	total: 662ms	remaining: 2.49s
# 21:	learn: 0.0568654	total: 690ms	remaining: 2.45s
# 22:	learn: 0.0568336	total: 723ms	remaining: 2.42s
# 23:	learn: 0.0568065	total: 750ms	remaining: 2.37s
# 24:	learn: 0.0567931	total: 777ms	remaining: 2.33s
# 25:	learn: 0.0567734	total: 806ms	remaining: 2.29s
# 26:	learn: 0.0567580	total: 832ms	remaining: 2.25s
# 27:	learn: 0.0567384	total: 859ms	remaining: 2.21s
# 28:	learn: 0.0567217	total: 887ms	remaining: 2.17s
# 29:	learn: 0.0567084	total: 915ms	remaining: 2.13s
# 30:	learn: 0.0567124	total: 942ms	remaining: 2.1s
# 31:	learn: 0.0566583	total: 967ms	remaining: 2.06s
# 32:	learn: 0.0566288	total: 993ms	remaining: 2.02s
# 33:	learn: 0.0566107	total: 1.02s	remaining: 1.98s
# 34:	learn: 0.0565952	total: 1.05s	remaining: 1.95s
# 35:	learn: 0.0565091	total: 1.08s	remaining: 1.91s
# 36:	learn: 0.0564881	total: 1.1s	remaining: 1.88s
# 37:	learn: 0.0564732	total: 1.13s	remaining: 1.84s
# 38:	learn: 0.0564450	total: 1.16s	remaining: 1.81s
# 39:	learn: 0.0564068	total: 1.19s	remaining: 1.78s
# 40:	learn: 0.0563865	total: 1.21s	remaining: 1.75s
# 41:	learn: 0.0562920	total: 1.24s	remaining: 1.71s
# 42:	learn: 0.0562786	total: 1.26s	remaining: 1.68s
# 43:	learn: 0.0562414	total: 1.29s	remaining: 1.65s
# 44:	learn: 0.0562276	total: 1.32s	remaining: 1.61s
# 45:	learn: 0.0562202	total: 1.35s	remaining: 1.58s
# 46:	learn: 0.0561974	total: 1.37s	remaining: 1.55s
# 47:	learn: 0.0561796	total: 1.4s	remaining: 1.52s
# 48:	learn: 0.0561630	total: 1.43s	remaining: 1.49s
# 49:	learn: 0.0561358	total: 1.46s	remaining: 1.46s
# 50:	learn: 0.0561167	total: 1.48s	remaining: 1.43s
# 51:	learn: 0.0561018	total: 1.51s	remaining: 1.4s
# 52:	learn: 0.0560949	total: 1.54s	remaining: 1.36s
# 53:	learn: 0.0560653	total: 1.57s	remaining: 1.34s
# 54:	learn: 0.0560551	total: 1.6s	remaining: 1.31s
# 55:	learn: 0.0560496	total: 1.63s	remaining: 1.28s
# 56:	learn: 0.0560425	total: 1.65s	remaining: 1.25s
# 57:	learn: 0.0560224	total: 1.68s	remaining: 1.22s
# 58:	learn: 0.0560197	total: 1.71s	remaining: 1.19s
# 59:	learn: 0.0560162	total: 1.73s	remaining: 1.16s
# 60:	learn: 0.0560085	total: 1.76s	remaining: 1.13s
# 61:	learn: 0.0559734	total: 1.79s	remaining: 1.1s
# 62:	learn: 0.0559679	total: 1.81s	remaining: 1.07s
# 63:	learn: 0.0558837	total: 1.84s	remaining: 1.04s
# 64:	learn: 0.0558690	total: 1.87s	remaining: 1.01s
# 65:	learn: 0.0557724	total: 1.9s	remaining: 979ms
# 66:	learn: 0.0557463	total: 1.93s	remaining: 949ms
# 67:	learn: 0.0557044	total: 1.95s	remaining: 920ms
# 68:	learn: 0.0556982	total: 1.98s	remaining: 890ms
# 69:	learn: 0.0556943	total: 2.01s	remaining: 861ms
# 70:	learn: 0.0556872	total: 2.04s	remaining: 833ms
# 71:	learn: 0.0556842	total: 2.07s	remaining: 805ms
# 72:	learn: 0.0556556	total: 2.1s	remaining: 776ms
# 73:	learn: 0.0556448	total: 2.13s	remaining: 747ms
# 74:	learn: 0.0556353	total: 2.16s	remaining: 719ms
# 75:	learn: 0.0556230	total: 2.19s	remaining: 691ms
# 76:	learn: 0.0556182	total: 2.22s	remaining: 662ms
# 77:	learn: 0.0556134	total: 2.25s	remaining: 633ms
# 78:	learn: 0.0556080	total: 2.27s	remaining: 604ms
# 79:	learn: 0.0556045	total: 2.3s	remaining: 575ms
# 80:	learn: 0.0555708	total: 2.33s	remaining: 546ms
# 81:	learn: 0.0555484	total: 2.36s	remaining: 518ms
# 82:	learn: 0.0555413	total: 2.39s	remaining: 489ms
# 83:	learn: 0.0555386	total: 2.41s	remaining: 460ms
# 84:	learn: 0.0555238	total: 2.44s	remaining: 431ms
# 85:	learn: 0.0555121	total: 2.47s	remaining: 402ms
# 86:	learn: 0.0555098	total: 2.5s	remaining: 373ms
# 87:	learn: 0.0555038	total: 2.52s	remaining: 344ms
# 88:	learn: 0.0555034	total: 2.55s	remaining: 316ms
# 89:	learn: 0.0554968	total: 2.58s	remaining: 287ms
# 90:	learn: 0.0554908	total: 2.62s	remaining: 259ms
# 91:	learn: 0.0554820	total: 2.65s	remaining: 230ms
# 92:	learn: 0.0554794	total: 2.67s	remaining: 201ms
# 93:	learn: 0.0554770	total: 2.7s	remaining: 173ms
# 94:	learn: 0.0554768	total: 2.73s	remaining: 144ms
# 95:	learn: 0.0554728	total: 2.76s	remaining: 115ms
# 96:	learn: 0.0554700	total: 2.79s	remaining: 86.2ms
# 97:	learn: 0.0554687	total: 2.81s	remaining: 57.5ms
# 98:	learn: 0.0554672	total: 2.84s	remaining: 28.7ms
# 99:	learn: 0.0554664	total: 2.87s	remaining: 0us
